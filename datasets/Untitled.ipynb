# %%
yo = weather.sample(n=500).reset_index(drop=True)

# %%
yo.to_csv("weatherAUS.csv")

# %%
og_df = pd.read_csv("weatherAUS.csv", index_col = 0)
og_df.Date = pd.to_datetime(og_df.Date)

modified_df = og_df.loc[[not x for x in og_df["RainTomorrow"].isnull()]]

def transform_date(x):
    if x < datetime.datetime(2012, 1, 1): 
        return "1. Before 2012"
    elif x < datetime.datetime(2015, 1, 1): 
        return "2. After 2012, Before 2015"
    else:
        return "3. After 2015"
    
modified_df.Date = [transform_date(x) for x in modified_df.Date]

# %%
modified_df
# Out:
#                            Date          Location  MinTemp  MaxTemp  Rainfall  \
# 0    2. After 2012, Before 2015        Wollongong     15.6     21.9       0.2
# 1                1. Before 2012            Hobart      1.7     12.3       0.4
# 2                1. Before 2012      MountGambier     11.7     28.0       0.0
# 3    2. After 2012, Before 2015        WaggaWagga      0.4     11.8       0.0
# 4                1. Before 2012      PerthAirport     18.6     32.6       0.0
# ..                          ...               ...      ...      ...       ...
# 495               3. After 2015           Penrith     18.7     31.0       0.0
# 496              1. Before 2012          Watsonia      3.3     16.5       0.2
# 497               3. After 2015           Woomera     17.4     36.0       0.0
# 498  2. After 2012, Before 2015           Walpole      9.1     21.0       0.0
# 499  2. After 2012, Before 2015  MelbourneAirport     10.0     16.3       2.6
#
# ...

# %%
df = modified_df
new_df = binary_class.feature_types.cont_to_cat(df.drop("Date", axis=1), True)
new_df["Date"] = df["Date"]

# %%
list(binary_class.feature_types.psi(new_df,
                      "RainTomorrow",
                      "Date",
"2. After 2012, Before 2015",
                           "3. After 2015").psi)
# Out:
# [0.6024573756626945,
#  0.15809226869173842,
#  0.056775737122305256,
#  0.013624592156900404,
#  0.2345025218921846,
#  0.17033273295170107,
#  0.13430739281082052,
#  0.03464734670419742,
#  0.3224620265964764,
#  0.09812087671214752,
#  0.009674522543387354,
#  0.026468739454294933,
#  0.03627969465670946,
#  0.11139028305901766,
#  0.0842814397643875,
#  0.03882943099618481,
#  0.054284641264211744,
#  0.040488456041845144,
#  0.06833524924512668,
#  0.04451318470561884,
#  0.010596661888723668]

# %%
binary_class.feature_types.fill_missing(modified_df).to_csv("filledDf.csv")

# %%
binary_class.feature_types.cont_to_cat(modified_df, fillNA=True).to_csv("contocatDf.csv")

# %%
binary_class.feature_types.labelled_df(modified_df).to_csv("labelledDf.csv")
# Out:
#      Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       1        47     15.6     21.9       0.2          NaN       NaN
# 1       0        15      1.7     12.3       0.4          1.4       8.0
# 2       0        22     11.7     28.0       0.0          5.2       0.9
# 3       1        42      0.4     11.8       0.0          2.6       4.1
# 4       0        32     18.6     32.6       0.0         12.8      11.7
# ..    ...       ...      ...      ...       ...          ...       ...
# 495     2        30     18.7     31.0       0.0          NaN       NaN
# 496     0        44      3.3     16.5       0.2          1.0       6.4
# 497     2        48     17.4     36.0       0.0          NaN       NaN
# 498     1        43      9.1     21.0       0.0          NaN       NaN
# 499     1        19     10.0     16.3       2.6          1.0       0.2
#
#      WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
binary_class.feature_types.find_type(og_df, "DC")
# Out:
# ['Date']

# %%
modified_df
# Out:
#                            Date          Location  MinTemp  MaxTemp  Rainfall  \
# 0    2. After 2012, Before 2015        Wollongong     15.6     21.9       0.2
# 1                1. Before 2012            Hobart      1.7     12.3       0.4
# 2                1. Before 2012      MountGambier     11.7     28.0       0.0
# 3    2. After 2012, Before 2015        WaggaWagga      0.4     11.8       0.0
# 4                1. Before 2012      PerthAirport     18.6     32.6       0.0
# ..                          ...               ...      ...      ...       ...
# 495               3. After 2015           Penrith     18.7     31.0       0.0
# 496              1. Before 2012          Watsonia      3.3     16.5       0.2
# 497               3. After 2015           Woomera     17.4     36.0       0.0
# 498  2. After 2012, Before 2015           Walpole      9.1     21.0       0.0
# 499  2. After 2012, Before 2015  MelbourneAirport     10.0     16.3       2.6
#
# ...

# %%
column = "Cloud9am"
print(binary_class.feature_types.data_type(og_df, column))
print(binary_class.feature_types.data_type(og_df, column, 10))
# Out:
# NC
# N

# %%
fa_object = binary_class.feature_analysis(modified_df,
                             "RainTomorrow",
                             "Date",
                             bad_class="Yes")

# %%
fa_object.iv_scores("IV")
# Out:
# [0.6645,
#  0.0965,
#  0.1803,
#  0.4124,
#  0.1373,
#  1.1725,
#  0.232,
#  0.4716,
#  0.2337,
#  0.1986,
#  0.2184,
#  0.2617,
#  0.5284,
#  1.4659,
#  0.4514,
#  0.3586,
#  0.5495,
#  0.7481,
#  0.0407,
#  0.3072,
#  0.4635]

# %%
from feature_analysis import binary_class

# %%
binary_class.feature_types.cont_to_cat(a).to_csv("contocatDf.csv")

# %%
import feature

# %%
import pandas as pd
import datetime
pd.options.mode.chained_assignment = None 

## Data Preprocessing:
weather = pd.read_csv("weatherAUS.csv")
weather.Date = pd.to_datetime(weather.Date)
weather_test = weather.loc[[not x for x in weather["RainTomorrow"].isnull()]]

def transform_date(x):
    if x < datetime.datetime(2012, 1, 1): 
        return "1. Before 2012"
    elif x < datetime.datetime(2015, 1, 1): 
        return "2. After 2012, Before 2015"
    else:
        return "3. After 2015"
    
weather_test.Date = [transform_date(x) for x in weather_test.Date]

# %%
import feature_analysis

# %%
report.analysis()
# Out:
#          Features  Missing Count  Missing Rate (%)  Zero Count  Zero Rate (%)  \
# 0        Location              0              0.00           0           0.00
# 1         MinTemp            637              0.45         156           0.11
# 2         MaxTemp            322              0.23          14           0.01
# 3        Rainfall           1406              0.99       90275          63.49
# 4     Evaporation          60843             42.79         240           0.17
# 5        Sunshine          67816             47.69        2308           1.62
# 6     WindGustDir           9330              6.56           0           0.00
# 7   WindGustSpeed           9270              6.52           0           0.00
# 8      WindDir9am          10013              7.04           0           0.00
# 9      WindDir3pm           3778              2.66           0           0.00
# 10   WindSpeed9am           1348              0.95        8612           6.06
# ...

# %%
import pandas as pd

# %%
pd.read_csv("binned_date_df.csv",
                       index_col=0)
# Out:
#          Variable Metric  (2008-04-23 23:59:59.999999999, 2010-05-07]  \
# 0        Location    psi                                          NaN
# 1         MinTemp    psi                                          NaN
# 2         MaxTemp    psi                                          NaN
# 3        Rainfall    psi                                          NaN
# 4     Evaporation    psi                                          NaN
# 5        Sunshine    psi                                          NaN
# 6     WindGustDir    psi                                          NaN
# 7   WindGustSpeed    psi                                          NaN
# 8      WindDir9am    psi                                          NaN
# 9      WindDir3pm    psi                                          NaN
# 10   WindSpeed9am    psi                                          NaN
# 11   WindSpeed3pm    psi                                          NaN
# ...
